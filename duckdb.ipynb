# %%
# !uv pip install duckdb -q

# %%
# !uv pip install python-dotenv -q

# %%
# import pandas as pd

# %%
file_url = "s3://capstone-techcatalyst-raw/hvfhv/fhvhv_tripdata_2024-01.parquet"

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import duckdb

con = duckdb.connect("sample.db")

# %%
con.sql("""
  CREATE OR REPLACE SECRET my_s3 (
    TYPE s3,
    PROVIDER credential_chain
  );
""")
# Out:
# ┌─────────┐
# │ Success │
# │ boolean │
# ├─────────┤
# │ true    │
# └─────────┘

# %%
df = con.sql("SELECT * FROM read_parquet('s3://capstone-techcatalyst-raw/hvfhv/fhvhv_tripdata_2024-01.parquet') LIMIT 1000000").fetchdf()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
df.shape
# Out:
# (1000000, 24)
