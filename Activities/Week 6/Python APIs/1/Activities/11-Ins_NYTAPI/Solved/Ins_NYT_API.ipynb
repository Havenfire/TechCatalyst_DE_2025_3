# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "granola"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = articles["response"]["docs"]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://article/bc4b0234-668c-52c1-a432-22ac7a4d5be6',
#   'abstract': 'I like it with Greek yogurt, but it’s terrific with whole milk, '
#               'too, and doesn’t do poorly at all on its own, like a kind of '
#               'trail mix.',
#   'byline': {'original': 'By Sam Sifton'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'Eleven Madison Park Granola, Surprisingly Easy and '
#                        'Very Snackable',
#                'print_headline': ''},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Cooking and Cookbooks'},
#                {'name': 'Subject',
#                 'rank': 2,
#                 'value': 'Content Type: Service'}],
#   'multimedia': {'caption': 'Daniel Humm’s Eleven Madison Park granola, '
#                             'adapted by Sam Sifton.',
#                  'credit': 'Ryan Liebe for The New York Times. Food Stylist: '
#                            'Barrett Washburne. Prop Stylist: Megan Hedgpeth.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2024/01/22/multimedia/22MadParkGranola-rex-flwc-copy-NL/22MadParkGranola-rex-flwc-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2024/01/22/multimedia/22MadParkGranola-rex-flwc-copy-NL/22MadParkGranola-rex-flwc-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2025-01-26T16:00:02Z',
#   'section_name': 'Food',
#   'snippet': 'I like it with Greek yogurt, but it’s terrific with whole milk, '
#              'too, and doesn’t do poorly at all on its own, like a kind of '
#              'trail mix.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'Letter',
#   'uri': 'nyt://article/bc4b0234-668c-52c1-a432-22ac7a4d5be6',
#   'web_url': 'https://www.nytimes.com/2025/01/26/dining/eleven-madison-park-granola-surprisingly-easy-and-very-snackable.html',
#   'word_count': 761},
#  {'_id': 'nyt://article/e1121419-4521-599b-a41f-84a1e79024dd',
#   'abstract': 'This liminal-space week is a good time to fill your fridge, '
#               'freezer and pantry with delicious, sustaining things.',
#   'byline': {'original': 'By Tanya Sichynsky'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'Vegetable Dumplings, Oven Beans and Ginger Sesame '
#                        'Granola',
#                'print_headline': ''},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Cooking and Cookbooks'},
#                {'name': 'Subject', 'rank': 2, 'value': 'Content Type: Service'},
#                {'name': 'Subject', 'rank': 3, 'value': 'Recipes'}],
#   'multimedia': {'caption': "Cybelle Tondu's ginger sesame granola.",
#                  'credit': 'Christopher Testani for The New York Times. Food '
#                            'Stylist: Simon Andrews.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2024/12/17/multimedia/CT-Ginger-Sesame-Granolarex-whgj-copy/CT-Ginger-Sesame-Granolarex-whgj-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2024/12/17/multimedia/CT-Ginger-Sesame-Granolarex-whgj-copy/CT-Ginger-Sesame-Granolarex-whgj-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2024-12-26T18:00:01Z',
#   'section_name': 'Food',
#   'snippet': 'This liminal-space week is a good time to fill your fridge, '
#              'freezer and pantry with delicious, sustaining things.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/e1121419-4521-599b-a41f-84a1e79024dd',
#   'web_url': 'https://www.nytimes.com/2024/12/26/dining/vegetable-dumplings-oven-beans-and-ginger-sesame-granola.html',
#   'word_count': 541},
#  {'_id': 'nyt://article/ecb3a263-5a62-54ec-b50a-3a43c7dff311',
#   'abstract': 'Weekend kitchen shenanigans to keep everyone festive and fed.',
#   'byline': {'original': 'By Sam Sifton'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'Mushroom Bourguignon, Ginger Sesame Granola and Fried '
#                        'Eggplant Heroes',
#                'print_headline': ''},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Cooking and Cookbooks'},
#                {'name': 'Subject', 'rank': 2, 'value': 'Content Type: Service'},
#                {'name': 'Subject', 'rank': 3, 'value': 'Recipes'},
#                {'name': 'Subject', 'rank': 4, 'value': 'Beef'},
#                {'name': 'Subject', 'rank': 5, 'value': 'Mushrooms'}],
#   'multimedia': {'caption': "Melissa Clark's mushroom Bourguignon.",
#                  'credit': 'David Malosh for The New York Times. Food Stylist: '
#                            'Simon Andrews.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2021/02/14/dining/31lessmeat2-copy/merlin_166152300_0264611b-15a4-4fee-a6ec-b1849725d790-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2021/02/14/dining/31lessmeat2-copy/31lessmeat2-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2024-12-20T16:00:03Z',
#   'section_name': 'Food',
#   'snippet': 'Weekend kitchen shenanigans to keep everyone festive and fed.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'Letter',
#   'uri': 'nyt://article/ecb3a263-5a62-54ec-b50a-3a43c7dff311',
#   'web_url': 'https://www.nytimes.com/2024/12/20/dining/mushroom-bourguignon-ginger-sesame-granola-and-fried-eggplant-heroes.html',
#   'word_count': 701},
#  {'_id': 'nyt://article/250a7f52-542f-59f3-9b19-fcadf011716c',
#   'abstract': 'The 23-year-old hiker, Hadi Nazari, survived for almost two '
#               'weeks on two granola bars he found in a hut and on water from '
#               'rivers and creeks, the authorities said.',
#   'byline': {'original': 'By Sara Ruberg'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'Hiker Found Alive After 13 Days Lost in Australian '
#                        'Mountains',
#                'print_headline': ''},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Missing Persons'},
#                {'name': 'Subject', 'rank': 2, 'value': 'Hikes and Hiking'},
#                {'name': 'Subject', 'rank': 3, 'value': 'Wilderness Areas'},
#                {'name': 'Subject', 'rank': 4, 'value': 'Rescues'},
#                {'name': 'Location',
#                 'rank': 5,
#                 'value': 'New South Wales (Australia)'}],
#   'multimedia': {'caption': 'Hadi Nazari, shirtless in center, was lost for '
#                             'nearly two weeks after going hiking in Kosciuszko '
#                             'National Park.',
#                  'credit': "Australia's ABC, via Associated Press",
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2025/01/08/multimedia/08xp-hiker-mgkv/08xp-hiker-mgkv-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/01/08/multimedia/08xp-hiker-mgkv/08xp-hiker-mgkv-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Express',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2025-01-09T00:08:47Z',
#   'section_name': 'World',
#   'snippet': 'The 23-year-old hiker, Hadi Nazari, survived for almost two '
#              'weeks on two granola bars he found in a hut and on water from '
#              'rivers and creeks, the authorities said.',
#   'source': 'The New York Times',
#   'subsection_name': 'Australia',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/250a7f52-542f-59f3-9b19-fcadf011716c',
#   'web_url': 'https://www.nytimes.com/2025/01/08/world/australia/missing-hiker-australia-found.html',
#   'word_count': 525},
#  {'_id': 'nyt://article/4f33fea2-030f-5220-993e-705107f4c1f4',
#   'abstract': 'Is popcorn good for you? What about pizza, orange juice or '
#               'sushi? Or frozen yogurt, pork chops or quinoa? What foods are '
#               'healthy to eat?',
#   'byline': {'original': 'By The Learning Network'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'What’s Going On in This Graph? | May 7, 2025',
#                'print_headline': ''},
#   'keywords': [],
#   'multimedia': {'caption': 'This graph was originally published in 2016.',
#                  'credit': 'The New York Times',
#                  'default': {'height': 620,
#                              'url': 'https://static01.nyt.com/images/2025/05/01/learning/NutritionistGraphLN/NutritionistGraphLN-articleLarge.png',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/05/01/learning/NutritionistGraphLN/NutritionistGraphLN-thumbStandard.png',
#                                'width': 75}},
#   'news_desk': 'Learning',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2025-05-01T19:00:03Z',
#   'section_name': 'The Learning Network',
#   'snippet': 'Is popcorn good for you? What about pizza, orange juice or '
#              'sushi? Or frozen yogurt, pork chops or quinoa? What foods are '
#              'healthy to eat?',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/4f33fea2-030f-5220-993e-705107f4c1f4',
#   'web_url': 'https://www.nytimes.com/2025/05/01/learning/whats-going-on-in-this-graph-may-7-2025.html',
#   'word_count': 2172},
#  {'_id': 'nyt://article/f65ee5a2-5bd8-5a98-bf25-9dd466d378e2',
#   'abstract': 'Start the day right with these can’t-miss recipes.',
#   'byline': {'original': 'By Cathy Lo'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': '14 Easy Healthy Breakfasts to Make on Repeat',
#                'print_headline': ''},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Cooking and Cookbooks'},
#                {'name': 'Subject',
#                 'rank': 2,
#                 'value': 'Content Type: Service'}],
#   'multimedia': {'caption': '',
#                  'credit': 'Linda Xiao for The New York Times. Food Stylist: '
#                            'Monica Pierini.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2025/01/27/multimedia/27COOKING-HEALTHY-BREAKFAST-Matcha-Oats-fgwj/27COOKING-HEALTHY-BREAKFAST-Matcha-Oats-fgwj-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/01/27/multimedia/27COOKING-HEALTHY-BREAKFAST-Matcha-Oats-fgwj/27COOKING-HEALTHY-BREAKFAST-Matcha-Oats-fgwj-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2025-01-27T20:50:52Z',
#   'section_name': 'Food',
#   'snippet': 'Start the day right with these can’t-miss recipes.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'NYT Cooking',
#   'uri': 'nyt://article/f65ee5a2-5bd8-5a98-bf25-9dd466d378e2',
#   'web_url': 'https://cooking.nytimes.com/article/easy-healthy-breakfast-ideas',
#   'word_count': 915},
#  {'_id': 'nyt://article/996fdf4e-cd31-5a6a-b6bf-9674fb416c70',
#   'abstract': 'This simple recipe from Genevieve Ko gets the bulk of its '
#               'protein from nuts, not powders, for an especially delicious '
#               'on-the-go snack.',
#   'byline': {'original': 'By Genevieve Ko'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'The Best Protein Bars Are the Ones You Make at Home',
#                'print_headline': 'The Best Protein Bars Are Made at Home'},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Nuts'},
#                {'name': 'Subject', 'rank': 2, 'value': 'Snack Foods'},
#                {'name': 'Subject', 'rank': 3, 'value': 'Cooking and Cookbooks'},
#                {'name': 'Subject', 'rank': 4, 'value': 'Proteins'},
#                {'name': 'Subject',
#                 'rank': 5,
#                 'value': 'Content Type: Service'}],
#   'multimedia': {'caption': '',
#                  'credit': 'Rachel Vanni for The New York Times. Food Stylist: '
#                            'Spencer Richards.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2025/06/25/multimedia/25FD-KO-2-gcfw/25FD-KO-2-gcfw-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/06/25/multimedia/25FD-KO-2-gcfw/25FD-KO-2-gcfw-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '7',
#   'print_section': 'D',
#   'pub_date': '2025-06-25T18:54:31Z',
#   'section_name': 'Food',
#   'snippet': 'This simple recipe from Genevieve Ko gets the bulk of its '
#              'protein from nuts, not powders, for an especially delicious '
#              'on-the-go snack.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/996fdf4e-cd31-5a6a-b6bf-9674fb416c70',
#   'web_url': 'https://www.nytimes.com/2025/06/25/dining/how-to-make-protein-bars.html',
#   'word_count': 549},
#  {'_id': 'nyt://article/3dd5a519-02d1-507c-b557-0c3eb190345d',
#   'abstract': 'And it’s not chocolate chips.',
#   'byline': {'original': 'By Genevieve Ko'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'The Secret to Great Pancakes Has Been in Your Pantry '
#                        'All Along',
#                'print_headline': 'Pancakes With the Warmth of Porridge'},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Pancakes'},
#                {'name': 'Subject', 'rank': 2, 'value': 'Oatmeal'},
#                {'name': 'Subject', 'rank': 3, 'value': 'Content Type: Service'},
#                {'name': 'Subject',
#                 'rank': 4,
#                 'value': 'Cooking and Cookbooks'}],
#   'multimedia': {'caption': '',
#                  'credit': 'David Malosh for The New York Times. Food Stylist: '
#                            'Simon Andrews.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2025/03/12/multimedia/06KO-Pancake-promo-lqbg/06KO-Pancake-promo-lqbg-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/03/12/multimedia/06KO-Pancake-promo-lqbg/06KO-Pancake-promo-lqbg-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '2',
#   'print_section': 'D',
#   'pub_date': '2025-03-06T16:57:42Z',
#   'section_name': 'Food',
#   'snippet': 'And it’s not chocolate chips.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/3dd5a519-02d1-507c-b557-0c3eb190345d',
#   'web_url': 'https://www.nytimes.com/2025/03/06/dining/secret-to-best-pancakes.html',
#   'word_count': 551},
#  {'_id': 'nyt://article/1ceabf23-444b-5e8e-b796-f40f504ed6ea',
#   'abstract': 'This creamy butternut squash and coconut noodle soup from '
#               'Christian Reynoso boasts an incredible color and a perfectly '
#               'calibrated sour-spicy tang.',
#   'byline': {'original': 'By Melissa Clark'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'This Quick Noodle Soup Is Vivid in Every Sense of the '
#                        'Word',
#                'print_headline': ''},
#   'keywords': [{'name': 'Subject', 'rank': 1, 'value': 'Cooking and Cookbooks'},
#                {'name': 'Subject',
#                 'rank': 2,
#                 'value': 'Content Type: Service'}],
#   'multimedia': {'caption': 'Christian Reynoso’s creamy butternut squash and '
#                             'coconut noodle soup.',
#                  'credit': 'Kerri Brewer for The New York Times. Food Stylist: '
#                            'Barrett Washburne.',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2025/01/14/multimedia/CR-squash-coconut-lime-noodle-soup-vfkc-copy-nl/CR-squash-coconut-lime-noodle-soup-vfkc-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/01/14/multimedia/CR-squash-coconut-lime-noodle-soup-vfkc-copy-nl/CR-squash-coconut-lime-noodle-soup-vfkc-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '',
#   'print_section': '',
#   'pub_date': '2025-01-20T16:00:04Z',
#   'section_name': 'Food',
#   'snippet': 'This creamy butternut squash and coconut noodle soup from '
#              'Christian Reynoso boasts an incredible color and a perfectly '
#              'calibrated sour-spicy tang.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'Letter',
#   'uri': 'nyt://article/1ceabf23-444b-5e8e-b796-f40f504ed6ea',
#   'web_url': 'https://www.nytimes.com/2025/01/20/dining/quick-noodle-soup.html',
#   'word_count': 542},
#  {'_id': 'nyt://article/b011fdb1-f990-53f6-bca9-485c55e44112',
#   'abstract': 'They’re not here to make friends, they’re here to make '
#               'pancakes.',
#   'byline': {'original': 'By Tanya Sichynsky'},
#   'document_type': 'article',
#   'headline': {'kicker': '',
#                'main': 'What Is It About Breakfast on ‘Love Island’? (Hint: '
#                        'It’s Sex.)',
#                'print_headline': 'Where Proof of Passion Lies in the Pancakes'},
#   'keywords': [{'name': 'Title',
#                 'rank': 1,
#                 'value': 'Love Island USA (TV Program)'},
#                {'name': 'Title',
#                 'rank': 2,
#                 'value': 'Love Island (TV Program)'},
#                {'name': 'Subject', 'rank': 3, 'value': 'Reality Television'},
#                {'name': 'Subject', 'rank': 4, 'value': 'Pancakes'}],
#   'multimedia': {'caption': '',
#                  'credit': 'Peacock ',
#                  'default': {'height': 400,
#                              'url': 'https://static01.nyt.com/images/2025/07/09/multimedia/LOVE-ISLAND-BREAKFAST-cover1-pcmt/LOVE-ISLAND-BREAKFAST-cover1-pcmt-articleLarge.jpg',
#                              'width': 600},
#                  'thumbnail': {'height': 75,
#                                'url': 'https://static01.nyt.com/images/2025/07/09/multimedia/LOVE-ISLAND-BREAKFAST-cover1-pcmt/LOVE-ISLAND-BREAKFAST-cover1-pcmt-thumbStandard.jpg',
#                                'width': 75}},
#   'news_desk': 'Dining',
#   'print_page': '6',
#   'print_section': 'D',
#   'pub_date': '2025-07-10T09:00:53Z',
#   'section_name': 'Food',
#   'snippet': 'They’re not here to make friends, they’re here to make pancakes.',
#   'source': 'The New York Times',
#   'subsection_name': '',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/b011fdb1-f990-53f6-bca9-485c55e44112',
#   'web_url': 'https://www.nytimes.com/2025/07/10/dining/love-island-breakfast.html',
#   'word_count': 1079}]

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your Reading List
# https://www.nytimes.com/2025/01/26/dining/eleven-madison-park-granola-surprisingly-easy-and-very-snackable.html
# https://www.nytimes.com/2024/12/26/dining/vegetable-dumplings-oven-beans-and-ginger-sesame-granola.html
# https://www.nytimes.com/2024/12/20/dining/mushroom-bourguignon-ginger-sesame-granola-and-fried-eggplant-heroes.html
# https://www.nytimes.com/2025/01/08/world/australia/missing-hiker-australia-found.html
# https://www.nytimes.com/2025/05/01/learning/whats-going-on-in-this-graph-may-7-2025.html
# https://cooking.nytimes.com/article/easy-healthy-breakfast-ideas
# https://www.nytimes.com/2025/06/25/dining/how-to-make-protein-bars.html
# https://www.nytimes.com/2025/03/06/dining/secret-to-best-pancakes.html
# https://www.nytimes.com/2025/01/20/dining/quick-noodle-soup.html
# https://www.nytimes.com/2025/07/10/dining/love-island-breakfast.html
