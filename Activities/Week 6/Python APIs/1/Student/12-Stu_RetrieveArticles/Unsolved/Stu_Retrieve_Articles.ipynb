# %%
# Dependencies
import requests
from config import api_key
import json
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
term = "q=frog"
fq = "&end_date=20140101&"

# Search for articles published between a begin and end date

# Build url
full_url = url + term + fq + "api-key=" + api_key

# %%
# Retrieve articles
response = requests.get(full_url)
data = response.json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "Copyright (c) 2025 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "_id": "nyt://article/84955aad-403c-5be7-8af8-859ef3bd99b0",
#                 "abstract": "Though they are widespread throughout New York City, gray tree frogs are rarely noticed by park visitors or wetland hikers.",
#                 "byline": {
#                     "original": "By Dave Taft"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "City Room",
#                     "main": "A Frog of Special Skill",
#                     "print_headline": ""
#                 },
#                 "keywords": [
#                     {
#                         "name": "Subject",
#                         "rank": 1,
#                         "value": "Frogs"
#                     },
#                     {
#                         "name": "Location",
#                         "rank": 2,
#                         "value": "New York City"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "",
#                     "credit": "Dave Taft",
#                     "default": {
#                         "height": 720,
#                         "url": "https://static01.nyt.com/images/2013/06/02/nyregion/02NATURE/02NATURE-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/06/02/nyregion/02NATURE/02NATURE-thumbStandard.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "",
#                 "print_page": "",
#                 "print_section": "",
#                 "pub_date": "2013-06-01T02:35:55Z",
#                 "section_name": "New York",
#                 "snippet": "Though they are widespread throughout New York City, gray tree frogs are rarely noticed by park visitors or wetland hikers.",
#                 "source": "The New York Times",
#                 "subsection_name": "",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/84955aad-403c-5be7-8af8-859ef3bd99b0",
#                 "web_url": "https://cityroom.blogs.nytimes.com/2013/05/31/a-frog-of-special-skill/",
#                 "word_count": 498
#             },
#             {
#                 "_id": "nyt://article/96838abe-85be-5c02-8a36-689745a20a67",
#                 "abstract": "With the advent of nouvelle cuisine in the 1970s, frogs\u2019 legs lost their cachet. But search hard enough, and you will find a lover of cuisses de grenouilles.",
#                 "byline": {
#                     "original": "By Elaine Sciolino"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "Letter From Paris",
#                     "main": "More Than a Great Pair of Legs",
#                     "print_headline": "More Than a Great Pair of Legs"
#                 },
#                 "keywords": [
#                     {
#                         "name": "Person",
#                         "rank": 1,
#                         "value": "Sciolino, Elaine"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 2,
#                         "value": "Frogs"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 3,
#                         "value": "Cooking and Cookbooks"
#                     },
#                     {
#                         "name": "Location",
#                         "rank": 4,
#                         "value": "France"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 5,
#                         "value": "Marguin, Christophe"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "Frogs\u2019 legs before\u00a0saut\u00e9ing in a pan of melted butter.",
#                     "credit": "Philippe Schuller for The New York Times",
#                     "default": {
#                         "height": 400,
#                         "url": "https://static01.nyt.com/images/2013/06/12/dining/12PARIS_SPAN/12PARIS-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/06/12/dining/12PARIS_SPAN/12PARIS-thumbStandard.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "Dining",
#                 "print_page": "1",
#                 "print_section": "D",
#                 "pub_date": "2013-06-10T19:51:57Z",
#                 "section_name": "Food",
#                 "snippet": "With the advent of nouvelle cuisine in the 1970s, frogs\u2019 legs lost their cachet. But search hard enough, and you will find a lover of cuisses de grenouilles.",
#                 "source": "The New York Times",
#                 "subsection_name": "",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/96838abe-85be-5c02-8a36-689745a20a67",
#                 "web_url": "https://www.nytimes.com/2013/06/12/dining/frogs-legs-may-be-out-of-favor-but-not-flavor.html",
#                 "word_count": 1431
#             },
#             {
#                 "_id": "nyt://article/2e36b383-82e4-5b98-8aab-67dc2018ccef",
#                 "abstract": "The African clawed frog carries a disease that threatens hundreds of other amphibian species, new research shows.",
#                 "byline": {
#                     "original": "By Sindya N. Bhanoo"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "",
#                     "main": "Frog Once Used in Pregnancy Tests Spread Deadly Fungus",
#                     "print_headline": ""
#                 },
#                 "keywords": [
#                     {
#                         "name": "Subject",
#                         "rank": 1,
#                         "value": "Frogs"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 2,
#                         "value": "Amphibians"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 3,
#                         "value": "Fungi"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 4,
#                         "value": "Research"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "The African clawed frog.",
#                     "credit": "Adam Bewick",
#                     "default": {
#                         "height": 582,
#                         "url": "https://static01.nyt.com/images/2013/05/16/science/16frogs/16frogs-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/05/16/science/16frogs/16frogs-thumbStandard.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "Science",
#                 "print_page": "",
#                 "print_section": "",
#                 "pub_date": "2013-05-15T21:59:38Z",
#                 "section_name": "Science",
#                 "snippet": "The African clawed frog carries a disease that threatens hundreds of other amphibian species, new research shows.",
#                 "source": "The New York Times",
#                 "subsection_name": "",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/2e36b383-82e4-5b98-8aab-67dc2018ccef",
#                 "web_url": "https://www.nytimes.com/2013/05/16/science/frog-once-used-in-pregnancy-tests-spread-deadly-fungus.html",
#                 "word_count": 416
#             },
#             {
#                 "_id": "nyt://article/a2012137-9b13-5e80-bf22-be0d51593e77",
#                 "abstract": "Two new picture books about frogs are spectacularly illustrated. There the similarities end.",
#                 "byline": {
#                     "original": "By Pamela Paul"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "Children's Books",
#                     "main": "Frogs",
#                     "print_headline": ""
#                 },
#                 "keywords": [
#                     {
#                         "name": "Title",
#                         "rank": 1,
#                         "value": "999 Frogs Wake Up (Book)"
#                     },
#                     {
#                         "name": "Title",
#                         "rank": 2,
#                         "value": "Frog Song (Book)"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 3,
#                         "value": "Kimura, Ken"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 4,
#                         "value": "Books and Literature"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 5,
#                         "value": "Murakami, Yasunari"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 6,
#                         "value": "Guiberson, Brenda Z"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 7,
#                         "value": "Spirin, Gennady"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "",
#                     "credit": "From \"999 Frogs Wake Up\"",
#                     "default": {
#                         "height": 357,
#                         "url": "https://static01.nyt.com/images/2013/02/27/books/27childrens-1/27childrens-1-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/02/27/books/27childrens-1/27childrens-1-thumbStandard.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "Culture",
#                 "print_page": "",
#                 "print_section": "",
#                 "pub_date": "2013-02-27T16:15:21Z",
#                 "section_name": "Books",
#                 "snippet": "Two new picture books about frogs are spectacularly illustrated. There the similarities end.",
#                 "source": "The New York Times",
#                 "subsection_name": "",
#                 "type_of_material": "Review",
#                 "uri": "nyt://article/a2012137-9b13-5e80-bf22-be0d51593e77",
#                 "web_url": "https://www.nytimes.com/2013/02/27/books/999-frogs-wake-up-and-frog-song.html",
#                 "word_count": 581
#             },
#             {
#                 "_id": "nyt://article/c84ee852-9deb-50dd-86b2-d8a31c0e4ad7",
#                 "abstract": "It could be years before scientists succeed in bringing species back from extinction, but they are thinking of ways to give new life to creatures like woolly mammoths and weird frogs.",
#                 "byline": {
#                     "original": "By Gina Kolata"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "",
#                     "main": "So You\u2019re Extinct? Scientists Have Gleam in Eye",
#                     "print_headline": "So You\u2019re Extinct? Scientists Have Gleam in Eye"
#                 },
#                 "keywords": [
#                     {
#                         "name": "Person",
#                         "rank": 1,
#                         "value": "Kolata, Gina"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 2,
#                         "value": "Endangered and Extinct Species"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 3,
#                         "value": "Cloning"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 4,
#                         "value": "Genetic Engineering"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 5,
#                         "value": "DNA (Deoxyribonucleic Acid)"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 6,
#                         "value": "Woolly Mammoths"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "",
#                     "credit": "",
#                     "default": {
#                         "height": 338,
#                         "url": "https://static01.nyt.com/images/2014/02/27/science/tc-mammoth-still/tc-mammoth-still-articleLarge.png",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2014/02/27/science/tc-mammoth-still/tc-mammoth-still-thumbStandard.png",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "National",
#                 "print_page": "1",
#                 "print_section": "A",
#                 "pub_date": "2013-03-19T03:55:00Z",
#                 "section_name": "Science",
#                 "snippet": "It could be years before scientists succeed in bringing species back from extinction, but they are thinking of ways to give new life to creatures like woolly mammoths and weird frogs.",
#                 "source": "The New York Times",
#                 "subsection_name": "Environment",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/c84ee852-9deb-50dd-86b2-d8a31c0e4ad7",
#                 "web_url": "https://www.nytimes.com/2013/03/19/science/earth/research-to-bring-back-extinct-frog-points-to-new-path-and-quandaries.html",
#                 "word_count": 1131
#             },
#             {
#                 "_id": "nyt://article/3d768cc0-36bd-5eb0-bc14-966456d406d0",
#                 "abstract": "To the chagrin of the artist, the city of Venice plans to remove the 2009 sculpture \u201cBoy With a Frog\u201d from a pivotal spot next to the Punta della Dogana museum.",
#                 "byline": {
#                     "original": "By Carol Vogel"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "",
#                     "main": "\u2018Boy With Frog\u2019 to Be Removed in Venice",
#                     "print_headline": ""
#                 },
#                 "keywords": [
#                     {
#                         "name": "Person",
#                         "rank": 1,
#                         "value": "Vogel, Carol"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 2,
#                         "value": "Ray, Charles (1953- )"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 3,
#                         "value": "Art"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 4,
#                         "value": "Sculpture"
#                     },
#                     {
#                         "name": "Location",
#                         "rank": 5,
#                         "value": "Venice (Italy)"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "\u201cBoy With Frog,\u201d a commissioned sculpture by Charles Ray, outside the Punta della Dogana art museum in Venice.",
#                     "credit": "Todd Heisler/The New York Times",
#                     "default": {
#                         "height": 400,
#                         "url": "https://static01.nyt.com/images/2013/05/03/arts/03VOGEL_SPAN/VOGEL-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/05/03/arts/03VOGEL_SPAN/VOGEL-thumbStandard.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "Weekend",
#                 "print_page": "24",
#                 "print_section": "C",
#                 "pub_date": "2013-05-02T20:29:37Z",
#                 "section_name": "Arts",
#                 "snippet": "To the chagrin of the artist, the city of Venice plans to remove the 2009 sculpture \u201cBoy With a Frog\u201d from a pivotal spot next to the Punta della Dogana museum.",
#                 "source": "The New York Times",
#                 "subsection_name": "Art & Design",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/3d768cc0-36bd-5eb0-bc14-966456d406d0",
#                 "web_url": "https://www.nytimes.com/2013/05/03/arts/design/boy-with-frog-to-be-removed-in-venice.html",
#                 "word_count": 1079
#             },
#             {
#                 "_id": "nyt://article/15cfb9b5-b19e-5dd9-966f-8cc386ac4995",
#                 "abstract": "An interactive Web site, periodically updated, visualizes the occurrence of cases of amphibian chytrid fungus around the world.",
#                 "byline": {
#                     "original": "By Rachel Nuwer"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "Green",
#                     "main": "Mapping a Plague of Frogs",
#                     "print_headline": ""
#                 },
#                 "keywords": [
#                     {
#                         "name": "Subject",
#                         "rank": 1,
#                         "value": "Amphibians"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 2,
#                         "value": "Forests and Forestry"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 3,
#                         "value": "Frogs"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 4,
#                         "value": "Fungi"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 5,
#                         "value": "Global Warming"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 6,
#                         "value": "Maps"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 7,
#                         "value": "Research"
#                     },
#                     {
#                         "name": "Organization",
#                         "rank": 8,
#                         "value": "Forest Service"
#                     },
#                     {
#                         "name": "Organization",
#                         "rank": 9,
#                         "value": "Oregon State University"
#                     },
#                     {
#                         "name": "Organization",
#                         "rank": 10,
#                         "value": "PLoS One"
#                     },
#                     {
#                         "name": "Location",
#                         "rank": 11,
#                         "value": "Central America"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "The incidence of chytrid fungal disease in North America. Researchers are working to chart occurrences of the fungus, a threat to many amphibian species around the globe.",
#                     "credit": "Bd-Maps",
#                     "default": {
#                         "height": 272,
#                         "url": "https://static01.nyt.com/images/2013/02/27/blogs/fungus2/fungus2-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/02/27/blogs/fungus2/fungus2-thumbStandard.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "",
#                 "print_page": "",
#                 "print_section": "",
#                 "pub_date": "2013-02-27T22:01:52Z",
#                 "section_name": "Science",
#                 "snippet": "An interactive Web site, periodically updated, visualizes the occurrence of cases of amphibian chytrid fungus around the world.",
#                 "source": "The New York Times",
#                 "subsection_name": "Environment",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/15cfb9b5-b19e-5dd9-966f-8cc386ac4995",
#                 "web_url": "https://green.blogs.nytimes.com/2013/02/27/mapping-a-plague-of-frogs/",
#                 "word_count": 893
#             },
#             {
#                 "_id": "nyt://article/ef5c6562-c0c3-596e-a5fa-bd40f9ff350a",
#                 "abstract": "Baseball\u2019s ceremonial first pitch, a pregame ritual once reserved for presidents, war heroes and mayors, has become little more than a marketing opportunity.",
#                 "byline": {
#                     "original": "By Andrew Keh"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "",
#                     "main": "Tonight\u2019s Honored Guest on the Mound, a Backflipping Frog",
#                     "print_headline": "Tonight\u2019s Honored Guest on the Mound, a Backflipping Frog"
#                 },
#                 "keywords": [
#                     {
#                         "name": "Subject",
#                         "rank": 1,
#                         "value": "Baseball"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 2,
#                         "value": "Keh, Andrew"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 3,
#                         "value": "Advertising and Marketing"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "Hello Kitty got to do the honors before a Dodgers game in September 2011.",
#                     "credit": "Stephen Dunn/Getty Images",
#                     "default": {
#                         "height": 925,
#                         "url": "https://static01.nyt.com/images/2013/05/29/sports/baseball/PITCH-C/PITCH-C-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/05/29/sports/baseball/PITCH-C/PITCH-C-thumbStandard-v2.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "Sports",
#                 "print_page": "1",
#                 "print_section": "A",
#                 "pub_date": "2013-05-29T01:20:05Z",
#                 "section_name": "Sports",
#                 "snippet": "Baseball\u2019s ceremonial first pitch, a pregame ritual once reserved for presidents, war heroes and mayors, has become little more than a marketing opportunity.",
#                 "source": "The New York Times",
#                 "subsection_name": "Baseball",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/ef5c6562-c0c3-596e-a5fa-bd40f9ff350a",
#                 "web_url": "https://www.nytimes.com/2013/05/29/sports/baseball/baseballs-first-pitch-loses-its-exclusivity.html",
#                 "word_count": 1145
#             },
#             {
#                 "_id": "nyt://article/73a4d801-e139-5363-837f-cfe1131a8e70",
#                 "abstract": "Andy Mills, the president of Medline Industries, a maker of health care products, talks about the hit-and-miss process of innovation.",
#                 "byline": {
#                     "original": "By Adam Bryant"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "Corner Office",
#                     "main": "Want to Innovate? Get Ready to Kiss Some Frogs",
#                     "print_headline": "Want to Innovate? Get Ready to Kiss Some Frogs"
#                 },
#                 "keywords": [
#                     {
#                         "name": "Person",
#                         "rank": 1,
#                         "value": "Bryant, Adam"
#                     },
#                     {
#                         "name": "Subject",
#                         "rank": 2,
#                         "value": "Executives and Management (Theory)"
#                     },
#                     {
#                         "name": "Organization",
#                         "rank": 3,
#                         "value": "Medline Industries Inc"
#                     },
#                     {
#                         "name": "Person",
#                         "rank": 4,
#                         "value": "Mills, Andy"
#                     }
#                 ],
#                 "multimedia": {
#                     "caption": "Andy Mills, president of Medline Industries.",
#                     "credit": "Earl Wilson/The New York Times",
#                     "default": {
#                         "height": 916,
#                         "url": "https://static01.nyt.com/images/2013/04/05/business/05CORNERMILLS/05CORNERMILLS-articleLarge.jpg",
#                         "width": 600
#                     },
#                     "thumbnail": {
#                         "height": 75,
#                         "url": "https://static01.nyt.com/images/2013/04/05/business/05CORNERMILLS/05CORNERMILLS-thumbStandard-v2.jpg",
#                         "width": 75
#                     }
#                 },
#                 "news_desk": "Business",
#                 "print_page": "2",
#                 "print_section": "B",
#                 "pub_date": "2013-04-04T13:02:17Z",
#                 "section_name": "Business",
#                 "snippet": "Andy Mills, the president of Medline Industries, a maker of health care products, talks about the hit-and-miss process of innovation.",
#                 "source": "The New York Times",
#                 "subsection_name": "",
#                 "type_of_material": "Question",
#                 "uri": "nyt://article/73a4d801-e139-5363-837f-cfe1131a8e70",
#                 "web_url": "https://www.nytimes.com/2013/04/05/business/want-to-innovate-get-ready-to-kiss-some-frogs.html",
#                 "word_count": 1137
#             },
#             {
#                 "_id": "nyt://article/8bb93f4a-c762-5e6d-a412-10ef3ac2f673",
#                 "abstract": "Sometimes this city makes you feel as if you\u2019re small enough to be trapped in a bag of lettuce.",
#                 "byline": {
#                     "original": "By ANELISE CHEN"
#                 },
#                 "document_type": "article",
#                 "headline": {
#                     "kicker": "Townies",
#                     "main": "The Christmas Frog",
#                     "print_headline": "The Tale of the Christmas Frog"
#                 },
#                 "keywords": [],
#                 "multimedia": {
#                     "caption": "",
#                     "credit": "",
#                     "default": {
#                         "height": 0,
#                         "url": "",
#                         "width": 0
#                     },
#                     "thumbnail": {
#                         "height": 0,
#                         "url": "",
#                         "width": 0
#                     }
#                 },
#                 "news_desk": "",
#                 "print_page": "9",
#                 "print_section": "SR",
#                 "pub_date": "2012-12-20T16:51:20Z",
#                 "section_name": "Opinion",
#                 "snippet": "Sometimes this city makes you feel as if you\u2019re small enough to be trapped in a bag of lettuce.",
#                 "source": "The New York Times",
#                 "subsection_name": "",
#                 "type_of_material": "News",
#                 "uri": "nyt://article/8bb93f4a-c762-5e6d-a412-10ef3ac2f673",
#                 "web_url": "https://opinionator.blogs.nytimes.com/2012/12/20/the-christmas-frog/",
#                 "word_count": 1045
#             }
#         ],
#         "metadata": {
#             "hits": 10000,
#             "offset": 0,
#             "time": 166
#         }
#     },
#     "status": "OK"
# }

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param
